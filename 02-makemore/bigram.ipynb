# %% [markdown]
# # Day 2 — bigram
# Bigram name model, from memory.

# %%
# BOILERPLATE: imports + dataset (32,033 names, already downloaded to this folder)
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

words = open('names.txt', 'r').read().splitlines()
print(len(words), words[:5])
